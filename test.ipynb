# %%
import os
from openai import OpenAI

client = OpenAI(api_key="sk-gMIR9DYnckJUG1qBnii6VUbHHHR9_WefdSI5LliNnJT3BlbkFJzXnESdeQS2zF358vyariY6qxz-BIn7Bqee4OzyaoYA")

resp = client.responses.create(
    model="gpt-4.1-mini",
    input="hi"
)

print(resp.output_text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 from openai import OpenAI
# ----> 4 client = OpenAI(api_key=os.environ["sk-gMIR9DYnckJUG1qBnii6VUbHHHR9_WefdSI5LliNnJT3BlbkFJzXnESdeQS2zF358vyariY6qxz-BIn7Bqee4OzyaoYA"])
#       6 resp = client.responses.create(
#       7     model="gpt-4.1-mini",
#       8     input="hi"
#       9 )
#      11 print(resp.output_text)
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'sk-gMIR9DYnckJUG1qBnii6VUbHHHR9_WefdSI5LliNnJT3BlbkFJzXnESdeQS2zF358vyariY6qxz-BIn7Bqee4OzyaoYA'
